# %% [markdown]
# # In this NoteBook we try will to showcase our idea to evaluate the O-line & D-line play in football games
#
# ## and as we all know that most of the stats does not eval the O-lineman correctly at all so we found a way to better eavl line play by taking to a count banh of things that we belive to be important to evalion line play.

# %%
import pandas as pd

# %%
games = pd.read_csv('../data/games.csv')
play = pd.read_csv('../data/plays.csv')
players = pd.read_csv('../data/players.csv')
pff = pd.read_csv('../data/pffScoutingData.csv')
week1 = pd.read_csv('../data/week1.csv')

# %%
# thse are all needed arrgs to cal_score
# gameid, nflid, 
# pff table: pff_role, pff_hurryAllowed, pff_sackAllowed, pff_hitAllowed, pff_beatenByDefender, pff_blockType
# plays table: quarter, yardsToGo, possessionTeam, passResult, offenseFormation, personnelO
# make a 1 for a boolean and scale for numerical veribles like how many penalty yards

# %% [markdown]
# ## Pick the game and the player & pass it the function and the model will eval the player in the game out of 10

# %%
# pff_role
roles= ['Pass Block']

# pff_positionLinedUp
pos = ['LT', 'LG', 'C', 'RG', 'RT']

# plays

# %%
def cal_score(gameid, nflid):
    # filter teh pff data
    pff_info = pff[pff.eval(f"gameId == {gameid} & nflId == {nflid} & pff_role in {roles} & pff_positionLinedUp in {pos}")]
   
    # here we filter the play df to the game and play that the player prstpat at 
    play_info = play[play.eval(f"gameid == {gameid}")]
    
    pff_info = pff_info.iloc[:,3:6][pff_info.eval(f"quarter == 1")]

# %%
t = play.iloc[:,3:6][play.eval(f"quarter == 1")]
t
# Out:
#       quarter  down  yardsToGo
# 0           1     3          2
# 1           1     1         10
# 2           1     2          6
# 3           1     1         10
# 4           1     3         15
# ...       ...   ...        ...
# 8493        1     1         10
# 8494        1     2         10
# 8495        1     3         10
# 8496        1     1         10
# 8497        1     3         11
#
# [1735 rows x 3 columns]

# %%
play_info = play[play.eval(f"gameid == {gameid} & nflid == {nflid} ")]

# %%
pff_info['quarter'] = pff_info['playId'].apply(lambda x: play_info[][play_info.eval(f'playId == {x}')])
pff_info
# Out:
# 4         97
# 113      410
# 135      434
# 157      456
# 179      480
# 201      509
# 222      559
# 245      583
# 355      869
# 376      925
# 400      947
# 442     1203
# 464     1227
# 486     1267
# 509     1312
# 773     2008
# 795     2032
# 1015    2397
# 1037    2419
# 1060    2441
# 1235    2871
# 1257    2893
# 1279    2915
# 1322    3062
# 1344    3110
# 1367    3134
# 1521    3462
# 1542    3588
# 1565    3633
# 1587    3655
# 1653    3793
# 1674    3862
# 1696    3909
# 1718    3933
# 1741    3962
# 1940    4538
# 1962    4560
# 1984    4624
# 2006    4653
# 2028    4677
# 2048    4699
# 2071    4728
# 2094    4750
# 2116    4772
# Name: playId, dtype: int64

# %%
play_info = play[play.eval(f"gameId == 2021090900")]
play_info
# Out:
#         gameId  playId                                    playDescription  \
# 0   2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1   2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2   2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3   2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4   2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
# ..         ...     ...                                                ...
# 92  2021090900    4677  (:30) (No Huddle, Shotgun) T.Brady pass incomp...
# 93  2021090900    4699  (:24) (Shotgun) T.Brady pass deep left to C.Go...
# 94  2021090900    4728  (:18) (Shotgun) T.Brady pass incomplete short ...
# 95  2021090900    4750  (:14) (Shotgun) T.Brady pass incomplete short ...
# 96  2021090900    4772  (:10) (Shotgun) T.Brady pass incomplete short ...
#
#     quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# ...

# %%
# Out:
#         gameId  playId                                    playDescription  \
# 0   2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1   2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2   2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3   2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4   2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
# ..         ...     ...                                                ...
# 92  2021090900    4677  (:30) (No Huddle, Shotgun) T.Brady pass incomp...
# 93  2021090900    4699  (:24) (Shotgun) T.Brady pass deep left to C.Go...
# 94  2021090900    4728  (:18) (Shotgun) T.Brady pass incomplete short ...
# 95  2021090900    4750  (:14) (Shotgun) T.Brady pass incomplete short ...
# 96  2021090900    4772  (:10) (Shotgun) T.Brady pass incomplete short ...
#
#     quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# ...

# %%
week1['Q'], week1['D'], week1['Y'] = [t.iloc[:, :0], t.iloc[:, 0:1] , t.iloc[:, 1:2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
week1
# Out:
#              gameId  playId    nflId  frameId                     time  \
# 0        2021090900      97  25511.0        1  2021-09-10T00:26:31.100
# 1        2021090900      97  25511.0        2  2021-09-10T00:26:31.200
# 2        2021090900      97  25511.0        3  2021-09-10T00:26:31.300
# 3        2021090900      97  25511.0        4  2021-09-10T00:26:31.400
# 4        2021090900      97  25511.0        5  2021-09-10T00:26:31.500
# ...             ...     ...      ...      ...                      ...
# 1118117  2021091300    4845      NaN       30  2021-09-14T03:54:20.600
# 1118118  2021091300    4845      NaN       31  2021-09-14T03:54:20.700
# 1118119  2021091300    4845      NaN       32  2021-09-14T03:54:20.800
# 1118120  2021091300    4845      NaN       33  2021-09-14T03:54:20.900
# 1118121  2021091300    4845      NaN       34  2021-09-14T03:54:21.000
#
#          jerseyNumber      team playDirection      x      y      s     a  \
# ...
