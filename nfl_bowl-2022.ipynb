# %% [markdown]
# # In this NoteBook we try will to showcase our idea to evaluate the O-line & D-line play in football games
#
# ## and as we all know that most of the stats does not eval the O-lineman correctly at all so we found a way to better eavl line play by taking to a count banh of things that we belive to be important to evalion line play.

# %%
import pandas as pd

# %%
games = pd.read_csv('../data/games.csv')
play = pd.read_csv('../data/plays.csv')
players = pd.read_csv('../data/players.csv')
pff = pd.read_csv('../data/pffScoutingData.csv')
week1 = pd.read_csv('../data/week1.csv')

# %%
# thse are all needed arrgs to cal_score
# gameid, nflid, 
# pff table: pff_role, pff_hurryAllowed, pff_sackAllowed, pff_hitAllowed, pff_beatenByDefender, pff_blockType
# plays table: quarter, yardsToGo, possessionTeam, passResult, offenseFormation, personnelO
# make a 1 for a boolean and scale for numerical veribles like how many penalty yards

# %% [markdown]
# ## Pick the game and the player & pass it the function and the model will eval the player in the game out of 10

# %%
# pff_role  | The the acceptable roles in the evaluated plays
roles= ['Pass Block']

# pff_positionLinedUp | That evaluated positions
pos = ['LT', 'LG', 'C', 'RG', 'RT']

# plays

# %%
pff
# Out:
#             gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0       2021090900      97  25511        Pass                  QB      NaN
# 1       2021090900      97  35481  Pass Route                TE-L      NaN
# 2       2021090900      97  35634  Pass Route                 LWR      NaN
# 3       2021090900      97  39985  Pass Route                HB-R      NaN
# 4       2021090900      97  40151  Pass Block                   C      NaN
# ...            ...     ...    ...         ...                 ...      ...
# 188249  2021110100    4433  52507  Pass Block                  LT      NaN
# 188250  2021110100    4433  52546    Coverage               SCBoR      0.0
# 188251  2021110100    4433  52573  Pass Route               SLoWR      NaN
# 188252  2021110100    4433  52585   Pass Rush                 LEO      0.0
# 188253  2021110100    4433  53449  Pass Route                 LWR      NaN
#
#         pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# 0             NaN       NaN                   NaN             NaN
# 1             NaN       NaN                   NaN             NaN
# 2             NaN       NaN                   NaN             NaN
# 3             NaN       NaN                   NaN             NaN
# 4             NaN       NaN                   0.0             0.0
# ...           ...       ...                   ...             ...
# 188249        NaN       NaN                   0.0             0.0
# 188250        0.0       0.0                   NaN             NaN
# 188251        NaN       NaN                   NaN             NaN
# 188252        0.0       0.0                   NaN             NaN
# 188253        NaN       NaN                   NaN             NaN
#
#         pff_hurryAllowed  pff_sackAllowed  pff_nflIdBlockedPlayer  \
# 0                    NaN              NaN                     NaN
# 1                    NaN              NaN                     NaN
# 2                    NaN              NaN                     NaN
# 3                    NaN              NaN                     NaN
# 4                    0.0              0.0                 44955.0
# ...                  ...              ...                     ...
# 188249               1.0              0.0                 43338.0
# 188250               NaN              NaN                     NaN
# 188251               NaN              NaN                     NaN
# 188252               NaN              NaN                     NaN
# 188253               NaN              NaN                     NaN
#
#        pff_blockType  pff_backFieldBlock
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                 SW                 0.0
# ...              ...                 ...
# 188249            PP                 0.0
# 188250           NaN                 NaN
# 188251           NaN                 NaN
# 188252           NaN                 NaN
# 188253           NaN                 NaN
#
# [188254 rows x 15 columns]

# %%
def cal_score(gameid, nflid):
    # filter teh pff data
    pff_info = pff[pff.eval(f"gameId == {gameid} & nflId == {nflid} & pff_role in {roles} & pff_positionLinedUp in {pos}")]
   
    # here we filter the play df to the game and play that the player prstpat at 
    play_info = play[play.eval(f"gameid == {gameid}")]
    
    pff_info = pff_info.iloc[:,3:6][pff_info.eval(f"quarter == 1")]

# %%
t = play.iloc[:,3:6][play.eval("quarter == 1")]
t
# Out:
#       quarter  down  yardsToGo
# 0           1     3          2
# 1           1     1         10
# 2           1     2          6
# 3           1     1         10
# 4           1     3         15
# ...       ...   ...        ...
# 8493        1     1         10
# 8494        1     2         10
# 8495        1     3         10
# 8496        1     1         10
# 8497        1     3         11
#
# [1735 rows x 3 columns]

# %%
pff_info = pff[pff.eval(f"gameId == 2021090900 & nflId == {nflid} & pff_role in {roles} & pff_positionLinedUp in {pos}")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25336/1187014232.py in <module>
# ----> 1 pff_info = pff[pff.eval(f"gameId == 2021090900 & nflId == {nflid} & pff_role in {roles} & pff_positionLinedUp in {pos}")]
#
# NameError: name 'nflid' is not defined

# %%
play_info = play[play.eval(f"gameId == 2021090900 & playId == 97 ")]

# %%
pff_info = pff[pff.eval(f"gameId == 2021090900 & nflId == 40151 & pff_role in {roles} & pff_positionLinedUp in {pos}")]
pff_info

# %%
pff_info

# %%
pff_info = pff_info.sort_values(['playId'],
              ascending = [True])

plays_list = pff_info['playId'].tolist()
plays_list

# %%
week2 = play.sort_values(['playId'],
              ascending = [True])

# %%
play_info = play[play.eval(f"gameId == 2021090900 & playId in {plays_list}")]
play_info

# %%
test = play_info.iloc[:,3:4][play_info.eval(f"playId == 97")]
week1['te'] = test

# %%
week1

# %%
pff_info = pff_info.sort_values(['playId'],
              ascending = [True])

pff_info

# %%
week1
