# %%
# Importing Necessary Module
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mysql.connector
# from preloads import conut_position_inFormation 
# %matplotlib inline

# %%
games_df = pd.read_csv('./data/games.csv')
pff_scouting_df = pd.read_csv('./data/pffScoutingData.csv')
players_df = pd.read_csv('./data/players.csv')
plays_df = pd.read_csv('./data/plays.csv')
week1_df = pd.read_csv('./data/week1.csv')
week2_df = pd.read_csv('./data/week2.csv')
week3_df = pd.read_csv('./data/week3.csv')
week4_df = pd.read_csv('./data/week4.csv')
week5_df = pd.read_csv('./data/week5.csv')
week6_df = pd.read_csv('./data/week6.csv')
week7_df = pd.read_csv('./data/week7.csv')
week8_df = pd.read_csv('./data/week8.csv')

# %%
games_df.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2021090900    2021     1  09/09/2021        20:20:00           TB
# 1  2021091200    2021     1  09/12/2021        13:00:00          ATL
# 2  2021091201    2021     1  09/12/2021        13:00:00          BUF
# 3  2021091202    2021     1  09/12/2021        13:00:00          CAR
# 4  2021091203    2021     1  09/12/2021        13:00:00          CIN
#
#   visitorTeamAbbr
# 0             DAL
# 1             PHI
# 2             PIT
# 3             NYJ
# 4             MIN

# %%
plays_df.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          2             TB           DAL           TB
# 1        1     1         10            DAL            TB          DAL
# 2        1     2          6            DAL            TB          DAL
# 3        1     1         10            DAL            TB           TB
# 4        1     3         15            DAL            TB           TB
#
#    yardlineNumber  ... foulNFLId3  absoluteYardlineNumber  offenseFormation  \
# ...

# %%
pff_scouting_df.head()
# Out:
#        gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0  2021090900      97  25511        Pass                  QB      NaN
# 1  2021090900      97  35481  Pass Route                TE-L      NaN
# 2  2021090900      97  35634  Pass Route                 LWR      NaN
# 3  2021090900      97  39985  Pass Route                HB-R      NaN
# 4  2021090900      97  40151  Pass Block                   C      NaN
#
#    pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# 0        NaN       NaN                   NaN             NaN
# 1        NaN       NaN                   NaN             NaN
# 2        NaN       NaN                   NaN             NaN
# 3        NaN       NaN                   NaN             NaN
# 4        NaN       NaN                   0.0             0.0
#
#    pff_hurryAllowed  pff_sackAllowed  pff_nflIdBlockedPlayer pff_blockType  \
# 0               NaN              NaN                     NaN           NaN
# ...

# %%
players_df.head()
# Out:
#    nflId height  weight   birthDate collegeName officialPosition  \
# 0  25511    6-4     225  1977-08-03    Michigan               QB
# 1  28963    6-5     240  1982-03-02   Miami, O.               QB
# 2  29550    6-4     328  1982-01-22    Arkansas                T
# 3  29851    6-2     225  1983-12-02  California               QB
# 4  30078    6-2     228  1982-11-24     Harvard               QB
#
#           displayName
# 0           Tom Brady
# 1  Ben Roethlisberger
# 2        Jason Peters
# 3       Aaron Rodgers
# 4    Ryan Fitzpatrick

# %%
plays_df.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          2             TB           DAL           TB
# 1        1     1         10            DAL            TB          DAL
# 2        1     2          6            DAL            TB          DAL
# 3        1     1         10            DAL            TB           TB
# 4        1     3         15            DAL            TB           TB
#
#    yardlineNumber  ... foulNFLId3  absoluteYardlineNumber  offenseFormation  \
# ...

# %%
passResult = {
    'I':'Incomplete pass',
    'C':'Complete_pass',
    'S':'Sack',
    'R':'Run',
    'IN':'Intercepted'
}

# %%
OL_id_list = players[].apply(lambda x: )
# Out:
#   File "/var/folders/tj/l0k30f1106sdy80lfw8lgdgm0000gn/T/ipykernel_25047/587388835.py", line 1
#     OL_id_list = players[].apply(lambda x: )
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## This function calculates the blocking score for each OL play and adds it to a diffreect table.
#
# ###

# %%
def create_DB_Connection():

# Creating connection object
mydb = mysql.connector.connect(
    host = "localhost",
    user = "yourusername",
    password = "your_password"
)

return mydb
# Out:
#   File "/var/folders/tj/l0k30f1106sdy80lfw8lgdgm0000gn/T/ipykernel_25047/3396379891.py", line 4
#     mydb = mysql.connector.connect(
#     ^
# IndentationError: expected an indented block

# %%
def count_block_score():
    #b
# Out:
#   File "/var/folders/tj/l0k30f1106sdy80lfw8lgdgm0000gn/T/ipykernel_25047/1413233147.py", line 3
#
#     ^
# IndentationError: expected an indented block

# %%
df = df.assign(Product=lambda x: (x['Field_1'] * x['Field_2'] * x['Field_3']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tj/l0k30f1106sdy80lfw8lgdgm0000gn/T/ipykernel_25047/325114031.py in <module>
# ----> 1 df = df.assign(Product=lambda x: (x['Field_1'] * x['Field_2'] * x['Field_3']))
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Ideaes:
#     * Match up score for OL and ED
#     * Condition score for OL players:
#         * in diffcult cases like 3& long
#     * for each pressure allowed (all pff allowed in pff sctiong df) calculate to simulate the in game cases
#         becase in 3& long OL will allow pressure or the formathion does not help any OL man emtay formahtion
#
#
# ## Note:
#     * all pff allowed stuff are what they the line man souhed be cradided or not
#
# ## limitations:
#     * the bad thing is we can't sumlite the time to throw

# %%
import re

# By crateing a posions as dic with a defult values
pos_dic = {
    'QB':0,
    'RB':0,
    'WR':0,
    'TE':0,
    'DT':0,
    'S':0,
    'LB':0,
}

string_of_positions = "QB RB WR TE FB "

def conut_position_personnel(formation ):
    formation.replace(" ", "")
    # To separate the positions
    formation_arr = formation.split(',')
    try :
        for entry in formation_arr:
            latters = re.findall('[A-Z]', entry)
            pos = re.search(''.join(latters), string_of_positions)[0]
            number_of_players = int(re.findall('[0-9]', entry)[0])
            pos_dic [pos] = number_of_players
    except TypeError:
        print("can't find the position in the personnel ")
    

    return pos_dic

# %%
conut_position_personnel('1 RB, 1 TE, 3 WR ')
# Out:
# {'QB': 0, 'RB': 1, 'WR': 3, 'TE': 1, 'DT': 0, 'S': 0, 'LB': 0}

# %%
per = '1 RB, 1 TE, 3 WR'
formation_arr = per.split(',')

# %%
pos = re.search('wr', 'ewjbljhew vleqbwrvipeuvu')

# %%
w = pos[0]

# %%
latters = re.findall('[A-Z]', formation_arr[0])

pos = re.search(''.join(latters), string_of_positions)[0]
number_of_players = int(re.findall('[0-9]', formation_arr[0])[0])

# %%
''.join(re.findall('[A-Z]', formation_arr[0]))
# Out:
# 'RB'

# %%
pos
# Out:
# <re.Match object; span=(3, 5), match='RB'>

# %%
number_of_players
# Out:
# ['1']
